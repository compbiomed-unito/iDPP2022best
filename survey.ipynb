# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None
# %matplotlib inline

# %% [markdown]
# # Create Dataframe Merged

# %%
data_torino = pd.read_excel('preprocessed_data/torino.xlsx')
data_torino_survey = pd.read_excel('preprocessed_data/torino.xlsx', sheet_name=1)
data_torino_fvc = pd.read_excel('preprocessed_data/torino.xlsx', sheet_name=2)
data_lisbona = pd.read_excel('preprocessed_data/lisbona.xlsx')
data_lisbona_survey = pd.read_excel('preprocessed_data/lisbona.xlsx', sheet_name=1)
data_lisbona_fvc = pd.read_excel('preprocessed_data/lisbona.xlsx', sheet_name=2)

# %%
def convert_lisbona(dataframe):
    list_ref = []
    
    try:
        for ref in dataframe['REF']:
            if ref < 10:
                new_ref = 'LIS_000' + str(ref)
            elif ref < 100:
                new_ref = 'LIS_00' + str(ref)
            elif ref < 1000:
                new_ref = 'LIS_0' + str(ref)
            else:
                new_ref = 'LIS_' + str(ref)
            list_ref.append(new_ref)
        return list_ref
    
    except Exception as error:
        return dataframe['REF']
    
data_lisbona_survey['REF'] = convert_lisbona(data_lisbona_survey)
data_lisbona['REF'] = convert_lisbona(data_lisbona)
data_lisbona_fvc['REF'] = convert_lisbona(data_lisbona_fvc)

# %% [markdown]
# # Distribution Survey and FVC

# %%
survey_positive = data_torino_survey.groupby('REF')['SurveyFromDiagnosis'].apply(lambda x: x.abs().min())

# %%
plt.hist(survey_positive.values, bins=150)
plt.gca().set(title='Frequency Histogram - Turin', xlabel='SurveyFromDiagnosis', ylabel='Frequency');
plt.xlim(0,2000)
# Out:
# (0.0, 2000.0)

# %%
surveys = data_lisbona_survey.groupby('REF')['SurveyFromDiagnosis'].apply(lambda x: x.abs().min())

# %%
plt.hist(surveys.values, bins=150)
plt.gca().set(title='Frequency Histogram - Lisbona', xlabel='SurveyFromDiagnosis', ylabel='Frequency');
plt.xlim(0,2000)
# Out:
# (0.0, 2000.0)

# %%
survey_positive_fvc = data_torino_fvc.groupby('REF')['FVCFromDiagnosis'].apply(lambda x: x.abs().min())
plt.hist(survey_positive_fvc.values, bins=150)
plt.gca().set(title='Frequency Histogram - Turin_FVC', xlabel='FVCFromDiagnosis', ylabel='Frequency');
plt.xlim(0,2000)
# Out:
# (0.0, 2000.0)

# %%
surveys_fvc = data_lisbona_fvc.groupby('REF')['FVCFromDiagnosis'].apply(lambda x: x.abs().min())
plt.hist(surveys_fvc.values, bins=150)
plt.gca().set(title='Frequency Histogram - Lisbona_FVC', xlabel='FVCFromDiagnosis', ylabel='Frequency');
plt.xlim(0,2000)
# Out:
# (0.0, 2000.0)

# %% [markdown]
# # Preparation Static

# %%
data_torino.set_index('REF', inplace=True)
data_lisbona.set_index('REF', inplace=True)

print('Dati di Torino: ', data_torino.shape)
print('Dati di Lisbona: ', data_lisbona.shape)
# Out:
# Dati di Torino:  (3111, 36)
# Dati di Lisbona:  (1630, 36)

# %%
data_merged = pd.concat([data_torino, data_lisbona])
data_merged.head()
# Out:
#           Age_onset (years)  Gender Date Of Last visit or Death  Status  NIV
# REF
# TUR_0001          56.565400       2                  2010-05-10     1.0  1.0  \
# TUR_0002          57.247073       1                  2004-05-18     1.0  1.0
# TUR_0003          62.447639       1                  2012-10-27     1.0  1.0
# TUR_0004          82.238859       1                  2007-09-15     1.0  0.0
# TUR_0005          53.962367       2                  2004-02-03     1.0  0.0
#
#            Date_NIV  PEG   Date_PEG  UMNvsLMN  Onset  ...  SOD1 Mutation
# REF                                                   ...
# TUR_0001 2008-04-15  0.0 2010-05-10       2.0    1.0  ...             0.0  \
# TUR_0002 2003-08-15  1.0 2004-05-11       3.0    2.0  ...             0.0
# TUR_0003 2012-05-15  1.0 2011-06-27       3.0    1.0  ...             0.0
# TUR_0004 2007-09-15  0.0 2007-09-15       2.0    1.0  ...             NaN
# TUR_0005 2004-02-03  0.0 2004-02-03       3.0    1.0  ...             NaN
#
#           C9orf72 repeat-primed PCR result  TARDBP mutation  FUS mutation
# REF
# TUR_0001                               0.0              0.0           0.0  \
# TUR_0002                               0.0              0.0           0.0
# TUR_0003                               0.0              0.0           0.0
# TUR_0004                               NaN              NaN           NaN
# TUR_0005                               NaN              NaN           NaN
#
#           WaitingTime  WeightRelathion  NIVFromDiagnosis
# REF
# TUR_0001       -275.0        -0.058824            1186.0  \
# TUR_0002       -245.0         0.020408             212.0
# TUR_0003       -122.0        -0.012658             670.0
# TUR_0004       -366.0              NaN            1004.0
# TUR_0005       -608.0         0.000000             506.0
#
#           TracheostomyFromDiagnosis  PEGFromDiagnosis
# REF
# TUR_0001                        NaN            1941.0  \
# TUR_0002                        NaN             482.0
# TUR_0003                        NaN             347.0
# TUR_0004                        NaN            1004.0
# TUR_0005                        NaN             506.0
#
#           DateToDeathFromDiagnosis
# REF
# TUR_0001                    1956.0
# TUR_0002                     504.0
# TUR_0003                     850.0
# TUR_0004                    1019.0
# TUR_0005                     521.0
#
# [5 rows x 36 columns]

# %%
data_merged.shape
# Out:
# (4741, 36)

# %%
data_merged.dropna(subset=['Status', 'Age_onset (years)', 'NIVFromDiagnosis', 'WaitingTime'], inplace=True)

# %%
data_merged[['NIV', 'PEG']] = data_merged[['NIV', 'PEG']].fillna(value=0)

# %%
data_merged.drop(columns=['TracheostomyFromDiagnosis', 'TARDBP mutation', 
                          'FUS mutation', 'SOD1 Mutation '], inplace=True)

# %%
data_merged = pd.get_dummies(data_merged, columns=['UMNvsLMN', 
                                                   'Onset', 'ULvsLL', 'DistProx', 
                                                   'Side', 'ALS familiar history', 
                                                   'smoke', 'Blood hypertension', 
                                                   'Diabetes – type I / II', 'Dyslipidemia', 
                                                   'Thyroid disorder', 'Autoimmune disorder', 
                                                   'Stroke', 'Cardiac disease', 'Primary cancer', 
                                                   'C9orf72 repeat-primed PCR result'])

# %%
data_merged.isnull().groupby(data_merged.index.str[:3]).mean().T
# Out:
# REF                                        LIS       TUR
# Age_onset (years)                     0.000000  0.000000
# Gender                                0.000000  0.000000
# Date Of Last visit or Death           0.000000  0.000000
# Status                                0.000000  0.000000
# NIV                                   0.000000  0.000000
# Date_NIV                              0.000000  0.000000
# PEG                                   0.000000  0.000000
# Date_PEG                              0.000000  0.000000
# Height (m)                            0.211912  0.254581
# Weight at 1st visit (kg)              0.252038  0.246866
# Weightloss >10% (0-no; 1-yes)         0.416928  0.265188
# WaitingTime                           0.000000  0.000000
# WeightRelathion                       0.630721  0.266152
# NIVFromDiagnosis                      0.000000  0.000000
# PEGFromDiagnosis                      0.000000  0.000000
# DateToDeathFromDiagnosis              0.000000  0.000000
# UMNvsLMN_1.0                          0.000000  0.000000
# UMNvsLMN_2.0                          0.000000  0.000000
# UMNvsLMN_3.0                          0.000000  0.000000
# Onset_1.0                             0.000000  0.000000
# Onset_2.0                             0.000000  0.000000
# Onset_3.0                             0.000000  0.000000
# Onset_4.0                             0.000000  0.000000
# ULvsLL_0.0                            0.000000  0.000000
# ULvsLL_1.0                            0.000000  0.000000
# ULvsLL_2.0                            0.000000  0.000000
# ULvsLL_3.0                            0.000000  0.000000
# DistProx_0.0                          0.000000  0.000000
# DistProx_1.0                          0.000000  0.000000
# DistProx_2.0                          0.000000  0.000000
# DistProx_3.0                          0.000000  0.000000
# Side_0.0                              0.000000  0.000000
# Side_1.0                              0.000000  0.000000
# Side_2.0                              0.000000  0.000000
# Side_3.0                              0.000000  0.000000
# ALS familiar history_0.0              0.000000  0.000000
# ALS familiar history_1.0              0.000000  0.000000
# smoke_0.0                             0.000000  0.000000
# smoke_1.0                             0.000000  0.000000
# Blood hypertension_0.0                0.000000  0.000000
# Blood hypertension_1.0                0.000000  0.000000
# Diabetes – type I / II_0.0            0.000000  0.000000
# Diabetes – type I / II_1.0            0.000000  0.000000
# Dyslipidemia_0.0                      0.000000  0.000000
# Dyslipidemia_1.0                      0.000000  0.000000
# Thyroid disorder_0.0                  0.000000  0.000000
# Thyroid disorder_1.0                  0.000000  0.000000
# Autoimmune disorder_0.0               0.000000  0.000000
# Autoimmune disorder_1.0               0.000000  0.000000
# Stroke_0.0                            0.000000  0.000000
# Stroke_1.0                            0.000000  0.000000
# Cardiac disease_0.0                   0.000000  0.000000
# Cardiac disease_1.0                   0.000000  0.000000
# Primary cancer_0.0                    0.000000  0.000000
# Primary cancer_1.0                    0.000000  0.000000
# C9orf72 repeat-primed PCR result_0.0  0.000000  0.000000
# C9orf72 repeat-primed PCR result_1.0  0.000000  0.000000

# %%
data_merged=data_merged[data_merged['DateToDeathFromDiagnosis'] >= 0]

# %% [markdown]
# # Merge Survey-FVC with Static

# %%
data_torino_survey.drop(columns=['ALSFRS_TOT', 'Date1'], inplace=True)
data_lisbona_survey.drop(columns=['Date1'], inplace=True)

# %%
data_torino_fvc.drop(columns=['CODICE', 'N_SPIRO', 'DATA SPIRO', 'DateOfDiagnosis'], inplace=True)
data_lisbona_fvc.drop(columns=['Date1', 'DateOfDiagnosis'], inplace=True)

data_lisbona_fvc.rename(columns={'%FVC1 ':'%FVC'}, inplace=True)

# %%
data_torino_fvc_min = data_torino_fvc.groupby('REF').apply(lambda x: x.loc[abs(x['FVCFromDiagnosis']).sort_values().index[0],])
data_lisbona_fvc_min = data_lisbona_fvc.groupby('REF').apply(lambda x: x.loc[abs(x['FVCFromDiagnosis']).sort_values().index[0],])

data_torino_fvc_min.set_index('REF', inplace=True)
data_lisbona_fvc_min.set_index('REF', inplace=True)

# %%
data_torino_survey_min = data_torino_survey.groupby('REF').apply(lambda x: x.loc[abs(x['SurveyFromDiagnosis']).sort_values().index[0],])
data_lisbona_survey_min = data_lisbona_survey.groupby('REF').apply(lambda x: x.loc[abs(x['SurveyFromDiagnosis']).sort_values().index[0],])

data_torino_survey_min.set_index('REF', inplace=True)
data_lisbona_survey_min.set_index('REF', inplace=True)

# %%
data_torino_survey.set_index('REF', inplace=True)
data_lisbona_survey.set_index('REF', inplace=True)

data_torino_fvc.set_index('REF', inplace=True)
data_lisbona_fvc.set_index('REF', inplace=True)

print('Dati di Torino sulle Survey: ', data_torino_survey.shape)
print('Dati di Lisbona sulle Survey: ', data_lisbona_survey.shape)

print('Dati di Torino sulle FVC: ', data_torino_fvc.shape)
print('Dati di Lisbona sulle FVC: ', data_lisbona_fvc.shape)
# Out:
# Dati di Torino sulle Survey:  (15006, 13)
# Dati di Lisbona sulle Survey:  (7522, 13)
# Dati di Torino sulle FVC:  (2890, 2)
# Dati di Lisbona sulle FVC:  (2664, 2)

# %%
data_merged_fvc = pd.concat([data_torino_fvc_min, data_lisbona_fvc_min])

# %%
data_merged_survey = pd.concat([data_torino_survey_min, data_lisbona_survey_min])

# %%
data_merged = data_merged.join(data_merged_survey)
data_merged
# Out:
#           Age_onset (years)  Gender Date Of Last visit or Death  Status  NIV
# REF
# TUR_0001          56.565400       2                  2010-05-10     1.0  1.0  \
# TUR_0002          57.247073       1                  2004-05-18     1.0  1.0
# TUR_0003          62.447639       1                  2012-10-27     1.0  1.0
# TUR_0004          82.238859       1                  2007-09-15     1.0  0.0
# TUR_0005          53.962367       2                  2004-02-03     1.0  0.0
# ...                     ...     ...                         ...     ...  ...
# LIS_1725          39.460643       2                  2022-04-08     2.0  0.0
# LIS_1726          68.873374       2                  2022-04-07     2.0  0.0
# LIS_1727          78.392882       2                  2022-05-18     2.0  0.0
# LIS_1728          71.983573       1                  2022-04-08     2.0  1.0
# LIS_1729          36.000000       1                  2022-05-18     2.0  0.0
#
#            Date_NIV  PEG   Date_PEG  Height (m)  Weight at 1st visit (kg)
# REF
# TUR_0001 2008-04-15  0.0 2010-05-10        1.60                      68.0  \
# TUR_0002 2003-08-15  1.0 2004-05-11        1.73                      98.0
# TUR_0003 2012-05-15  1.0 2011-06-27        1.60                      79.0
# TUR_0004 2007-09-15  0.0 2007-09-15         NaN                       NaN
# TUR_0005 2004-02-03  0.0 2004-02-03        1.58                      60.0
# ...             ...  ...        ...         ...                       ...
# LIS_1725 2022-04-08  0.0 2022-04-08        1.62                      58.3
# LIS_1726 2022-04-07  0.0 2022-04-07        1.56                      54.0
# LIS_1727 2022-05-18  0.0 2022-05-18        1.55                      67.0
# LIS_1728 2022-01-01  0.0 2022-04-08        1.66                      64.0
# LIS_1729 2022-05-18  0.0 2022-05-18        1.80                      85.0
#
#           ...  ALSFRS_4  ALSFRS_5  ALSFRS_6  ALSFRS_7  ALSFRS_8  ALSFRS_9
# REF       ...
# TUR_0001  ...         4         4         4         4       3.0       3.0  \
# TUR_0002  ...         4         4         4         4       4.0       3.0
# TUR_0003  ...         4         3         4         4       4.0       4.0
# TUR_0004  ...         4         3         3         3       3.0       2.0
# TUR_0005  ...         3         4         4         4       4.0       4.0
# ...       ...       ...       ...       ...       ...       ...       ...
# LIS_1725  ...         1         2         2         3       3.0       3.0
# LIS_1726  ...         3         3         2         3       2.0       1.0
# LIS_1727  ...         4         4         3         3       3.0       3.0
# LIS_1728  ...         1         1         0         0       2.0       0.0
# LIS_1729  ...         3         2         3         4       4.0       4.0
#
#           ALSFRS_10  ALSFRS_11  ALSFRS_12  SurveyFromDiagnosis
# REF
# TUR_0001          4        4.0        4.0                247.0
# TUR_0002          4        4.0        4.0                  0.0
# TUR_0003          4        4.0        4.0                  0.0
# TUR_0004          4        4.0        4.0                 -9.0
# TUR_0005          4        4.0        4.0                  0.0
# ...             ...        ...        ...                  ...
# LIS_1725          4        4.0        4.0               1407.0
# LIS_1726          2        3.0        4.0                127.0
# LIS_1727          3        4.0        4.0                  6.0
# LIS_1728          2        2.0        2.0                 38.0
# LIS_1729          4        4.0        4.0                 47.0
#
# [4699 rows x 70 columns]

# %%
data_merged.dropna(subset=['SurveyFromDiagnosis'], inplace=True)

# %%
data_merged = data_merged[(data_merged['SurveyFromDiagnosis'] <= 30) & 
            (data_merged['SurveyFromDiagnosis'] >= -30)]

# %%
print('Shape of Merged with Survey without NaN:', data_merged.shape)
# Out:
# Shape of Merged with Survey without NaN: (2443, 70)

# %%
data_merged['SurveyFromDeath'] = (data_merged['DateToDeathFromDiagnosis'] - data_merged['SurveyFromDiagnosis'])

# %%
data_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2443 entries, TUR_0002 to LIS_1727
# Data columns (total 71 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Age_onset (years)                     2443 non-null   float64
#  1   Gender                                2443 non-null   int64
#  2   Date Of Last visit or Death           2443 non-null   datetime64[ns]
#  3   Status                                2443 non-null   float64
#  4   NIV                                   2443 non-null   float64
#  5   Date_NIV                              2443 non-null   datetime64[ns]
#  6   PEG                                   2443 non-null   float64
#  7   Date_PEG                              2443 non-null   datetime64[ns]
#  8   Height (m)                            2143 non-null   float64
#  9   Weight at 1st visit (kg)              2132 non-null   float64
#  10  Weightloss >10% (0-no; 1-yes)         1868 non-null   float64
#  11  WaitingTime                           2443 non-null   float64
#  12  WeightRelathion                       1724 non-null   float64
#  13  NIVFromDiagnosis                      2443 non-null   float64
#  14  PEGFromDiagnosis                      2443 non-null   float64
#  15  DateToDeathFromDiagnosis              2443 non-null   float64
#  16  UMNvsLMN_1.0                          2443 non-null   bool
#  17  UMNvsLMN_2.0                          2443 non-null   bool
#  18  UMNvsLMN_3.0                          2443 non-null   bool
#  19  Onset_1.0                             2443 non-null   bool
#  20  Onset_2.0                             2443 non-null   bool
#  21  Onset_3.0                             2443 non-null   bool
#  22  Onset_4.0                             2443 non-null   bool
#  23  ULvsLL_0.0                            2443 non-null   bool
#  24  ULvsLL_1.0                            2443 non-null   bool
#  25  ULvsLL_2.0                            2443 non-null   bool
#  26  ULvsLL_3.0                            2443 non-null   bool
#  27  DistProx_0.0                          2443 non-null   bool
#  28  DistProx_1.0                          2443 non-null   bool
#  29  DistProx_2.0                          2443 non-null   bool
#  30  DistProx_3.0                          2443 non-null   bool
#  31  Side_0.0                              2443 non-null   bool
#  32  Side_1.0                              2443 non-null   bool
#  33  Side_2.0                              2443 non-null   bool
#  34  Side_3.0                              2443 non-null   bool
#  35  ALS familiar history_0.0              2443 non-null   bool
#  36  ALS familiar history_1.0              2443 non-null   bool
#  37  smoke_0.0                             2443 non-null   bool
#  38  smoke_1.0                             2443 non-null   bool
#  39  Blood hypertension_0.0                2443 non-null   bool
#  40  Blood hypertension_1.0                2443 non-null   bool
#  41  Diabetes – type I / II_0.0            2443 non-null   bool
#  42  Diabetes – type I / II_1.0            2443 non-null   bool
#  43  Dyslipidemia_0.0                      2443 non-null   bool
#  44  Dyslipidemia_1.0                      2443 non-null   bool
#  45  Thyroid disorder_0.0                  2443 non-null   bool
#  46  Thyroid disorder_1.0                  2443 non-null   bool
#  47  Autoimmune disorder_0.0               2443 non-null   bool
#  48  Autoimmune disorder_1.0               2443 non-null   bool
#  49  Stroke_0.0                            2443 non-null   bool
#  50  Stroke_1.0                            2443 non-null   bool
#  51  Cardiac disease_0.0                   2443 non-null   bool
#  52  Cardiac disease_1.0                   2443 non-null   bool
#  53  Primary cancer_0.0                    2443 non-null   bool
#  54  Primary cancer_1.0                    2443 non-null   bool
#  55  C9orf72 repeat-primed PCR result_0.0  2443 non-null   bool
#  56  C9orf72 repeat-primed PCR result_1.0  2443 non-null   bool
#  57  ALSFRS_1                              2443 non-null   float64
#  58  ALSFRS_2                              2443 non-null   float64
#  59  ALSFRS_3                              2443 non-null   float64
#  60  ALSFRS_4                              2443 non-null   object
#  61  ALSFRS_5                              2443 non-null   object
#  62  ALSFRS_6                              2443 non-null   object
#  63  ALSFRS_7                              2443 non-null   object
#  64  ALSFRS_8                              2443 non-null   float64
#  65  ALSFRS_9                              2443 non-null   float64
#  66  ALSFRS_10                             2443 non-null   object
#  67  ALSFRS_11                             2443 non-null   float64
#  68  ALSFRS_12                             2443 non-null   float64
#  69  SurveyFromDiagnosis                   2443 non-null   float64
#  70  SurveyFromDeath                       2443 non-null   float64
# dtypes: bool(41), datetime64[ns](3), float64(21), int64(1), object(5)
# memory usage: 689.5+ KB

# %% [markdown]
# #### IMPORTANTE: Abbiamo scartato gli FVC poiché aggiungendoli e droppando quelli che hanno NaN e quelli che sono tra -30 giorni e 30 giorni dalla data della diagnosi sono alla fine 736 risultando troppi pochi pazienti.

# %%
data_merged['Status']=data_merged['Status'].apply(lambda x: False if x == 1.0 else True)
data_merged['Gender']=data_merged['Gender'].apply(lambda x: 0 if x == 1.0 else 1)

# %%
data_merged[['Status', 'SurveyFromDeath']].apply(tuple, axis=1)
# Out:
# REF
# TUR_0002     (False, 504.0)
# TUR_0003     (False, 850.0)
# TUR_0004    (False, 1028.0)
# TUR_0005     (False, 521.0)
# TUR_0006    (False, 1499.0)
#                  ...
# LIS_1711       (True, 34.0)
# LIS_1713        (True, 0.0)
# LIS_1714      (True, 111.0)
# LIS_1720        (True, 0.0)
# LIS_1727       (True, 41.0)
# Length: 2443, dtype: object
